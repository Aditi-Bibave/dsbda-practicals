# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 111  112            6.4           2.7            5.3           1.9
# 84    85            5.4           3.0            4.5           1.5
# 89    90            5.5           2.5            4.0           1.3
# 19    20            5.1           3.8            1.5           0.3
# 55    56            5.7           2.8            4.5           1.3
# 8      9            4.4           2.9            1.4           0.2
# 102  103            7.1           3.0            5.9           2.1
# 147  148            6.5           3.0            5.2           2.0
# 124  125            6.7           3.3            5.7           2.1
# 134  135            6.1           2.6            5.6           1.4
#
#              Species
# 111   Iris-virginica
# 84   Iris-versicolor
# 89   Iris-versicolor
# 19       Iris-setosa
# 55   Iris-versicolor
# 8        Iris-setosa
# 102   Iris-virginica
# 147   Iris-virginica
# 124   Iris-virginica
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
print(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(data[10:21])
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa

# %%
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa

# %%
specific_data=data[["Id","Species"]]
print(specific_data.head(10))
# Out:
#    Id      Species
# 0   1  Iris-setosa
# 1   2  Iris-setosa
# 2   3  Iris-setosa
# 3   4  Iris-setosa
# 4   5  Iris-setosa
# 5   6  Iris-setosa
# 6   7  Iris-setosa
# 7   8  Iris-setosa
# 8   9  Iris-setosa
# 9  10  Iris-setosa

# %%
data.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
data.loc[data["Species"] == "Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
data["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sum_data = data["SepalLengthCm"].sum()
mean_data = data["SepalLengthCm"].mean()
median_data = data["SepalLengthCm"].median()
print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333334
# Median: 5.8

# %%
min_data=data["SepalLengthCm"].min()
max_data=data["SepalLengthCm"].max()
print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 7.9

# %%
cols = data.columns
print(cols)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data1 = data[cols].select_dtypes(include='number')
# Create the new 'total_values' column by summing the numeric values
data["total_values"] = data1.sum(axis=1)

# %%
newcols={ "Id":"id",
"SepalLengthCm":"SepalLength",
"SepalWidthCm":"SepalWidth"}
data.rename(columns=newcols,inplace=True)

# %%
print(data.head())
# Out:
#    id  SepalLength  SepalWidth  PetalLengthCm  PetalWidthCm      Species  \
# 0   1          5.1         3.5            1.4           0.2  Iris-setosa
# 1   2          4.9         3.0            1.4           0.2  Iris-setosa
# 2   3          4.7         3.2            1.3           0.2  Iris-setosa
# 3   4          4.6         3.1            1.5           0.2  Iris-setosa
# 4   5          5.0         3.6            1.4           0.2  Iris-setosa
#
#    total_values
# 0          11.2
# 1          11.5
# 2          12.4
# 3          13.4
# 4          15.2

# %%
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_03bf8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03bf8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_03bf8_level0_col1" class="col_heading level0 col1" >SepalLength</th>
#       <th id="T_03bf8_level0_col2" class="col_heading level0 col2" >SepalWidth</th>
#       <th id="T_03bf8_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_03bf8_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#       <th id="T_03bf8_level0_col5" class="col_heading level0 col5" >Species</th>
#       <th id="T_03bf8_level0_col6" class="col_heading level0 col6" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03bf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03bf8_row0_col0" class="data row0 col0" >1</td>
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen', axis=0)
# Out:
# <style type="text/css">
# #T_aa25c_row0_col5, #T_aa25c_row1_col5, #T_aa25c_row2_col5, #T_aa25c_row3_col5, #T_aa25c_row4_col5, #T_aa25c_row5_col1, #T_aa25c_row5_col2, #T_aa25c_row5_col3, #T_aa25c_row5_col4, #T_aa25c_row5_col5, #T_aa25c_row6_col5, #T_aa25c_row7_col5, #T_aa25c_row8_col5, #T_aa25c_row9_col0, #T_aa25c_row9_col5, #T_aa25c_row9_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aa25c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa25c_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_aa25c_level0_col1" class="col_heading level0 col1" >SepalLength</th>
#       <th id="T_aa25c_level0_col2" class="col_heading level0 col2" >SepalWidth</th>
#       <th id="T_aa25c_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_aa25c_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
# ...

# %%
# Highlight max values only in numeric columns
data.style.highlight_max(subset=data.select_dtypes(include='number').columns, axis=0)
# Out:
# <style type="text/css">
# #T_f5b30_row15_col2, #T_f5b30_row100_col4, #T_f5b30_row109_col4, #T_f5b30_row118_col3, #T_f5b30_row131_col1, #T_f5b30_row144_col4, #T_f5b30_row148_col6, #T_f5b30_row149_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f5b30" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5b30_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_f5b30_level0_col1" class="col_heading level0 col1" >SepalLength</th>
#       <th id="T_f5b30_level0_col2" class="col_heading level0 col2" >SepalWidth</th>
#       <th id="T_f5b30_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_f5b30_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#       <th id="T_f5b30_level0_col5" class="col_heading level0 col5" >Species</th>
#       <th id="T_f5b30_level0_col6" class="col_heading level0 col6" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
data.isnull()
# Out:
#         id  SepalLength  SepalWidth  PetalLengthCm  PetalWidthCm  Species  \
# 0    False        False       False          False         False    False
# 1    False        False       False          False         False    False
# 2    False        False       False          False         False    False
# 3    False        False       False          False         False    False
# 4    False        False       False          False         False    False
# ..     ...          ...         ...            ...           ...      ...
# 145  False        False       False          False         False    False
# 146  False        False       False          False         False    False
# 147  False        False       False          False         False    False
# 148  False        False       False          False         False    False
# 149  False        False       False          False         False    False
#
#      total_values
# 0           False
# 1           False
# 2           False
# ...

# %%
null_values = data.isnull().sum()
print(null_values)
# Out:
# id               0
# SepalLength      0
# SepalWidth       0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# total_values     0
# dtype: int64

# %%
import ssl
import seaborn as sns
ssl._create_default_https_context = ssl._create_unverified_context
iris = sns.load_dataset("iris")
sns.heatmap(iris.select_dtypes(include='number').corr(), cmap="YlGnBu", linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %%
sns.heatmap(iris.select_dtypes(include='number').corr(), cmap="YlGnBu", linecolor='white', linewidths=1, annot=True)
# Out:
# <Axes: >

# %%
data.select_dtypes(include='number').corr(method='pearson')
# Out:
#                      id  SepalLength  SepalWidth  PetalLengthCm  PetalWidthCm  \
# id             1.000000     0.716676   -0.397729       0.882747      0.899759
# SepalLength    0.716676     1.000000   -0.109369       0.871754      0.817954
# SepalWidth    -0.397729    -0.109369    1.000000      -0.420516     -0.356544
# PetalLengthCm  0.882747     0.871754   -0.420516       1.000000      0.962757
# PetalWidthCm   0.899759     0.817954   -0.356544       0.962757      1.000000
# total_values   0.999370     0.738612   -0.389048       0.897059      0.911904
#
#                total_values
# id                 0.999370
# SepalLength        0.738612
# SepalWidth        -0.389048
# PetalLengthCm      0.897059
# PetalWidthCm       0.911904
# total_values       1.000000

# %%
g=sns.pairplot(data,hue="Species")
